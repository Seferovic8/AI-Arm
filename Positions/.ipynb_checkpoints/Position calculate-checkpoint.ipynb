# %%
import cv2
import cv2.aruco as aruco
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load image
img = cv2.imread("../bvrctlzi.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
# Detect aruco markers
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
arucoDict = dictionary = aruco.getPredefinedDictionary(aruco.DICT_4X4_50)
arucoParams = aruco.DetectorParameters()
detector = aruco.ArucoDetector(dictionary, arucoParams)
markerCorners, markerIds, rejectedCandidates = detector.detectMarkers(img)
aruco.drawDetectedMarkers(img,markerCorners)
markerCorners=np.squeeze(markerCorners)
print("done")
# Out:
# done

# %%
# Show image with aruco markers
plt.imshow(img)

# %%
# Find the minimum bounding rectangle
rect = cv2.minAreaRect(markerCorners[0].reshape((-1, 1, 2)))

# Extract the center and other information from the rectangle
center, size, angle = rect

# Print the center coordinates
print("Center coordinates of marker 0 is:", np.round(center))
# Out:
# Center coordinates of marker 0 is: [107. 522.]

# %%
markerDetails={}
for i,ida in enumerate(markerIds):
    rect = cv2.minAreaRect(markerCorners[i].reshape((-1, 1, 2)))
    # Extract the center and other information from the rectangle
    center, size, angle = rect
    markerDetails[ida[0]]=np.array([np.round(center),np.round(size)],dtype=np.int16)
markerDetails
# Out:
# {2: array([[107, 522],
#         [ 31,  46]], dtype=int16),
#  1: array([[590, 513],
#         [ 46,  32]], dtype=int16),
#  0: array([[527,  44],
#         [ 29,  24]], dtype=int16)}

# %%
markerCorners[0]
# Out:
# array([[ 95., 500.],
#        [124., 500.],
#        [121., 544.],
#        [ 90., 544.]], dtype=float32)

# %%
markerIds
# Out:
# array([[2],
#        [1],
#        [0]], dtype=int32)

# %%
markerDetails[0][0]
# Out:
# array([527,  44], dtype=int16)

# %%
cv2.line(img, markerDetails[0][0], markerDetails[1][0], (255, 0, 0), thickness=3)
cv2.line(img, markerDetails[1][0],markerDetails[2][0], (0, 255, 0), thickness=3)
cv2.line(img, markerDetails[0][0],markerDetails[2][0], (0, 0, 255), thickness=3)

print("done")
# Out:
# done

# %%
plt.imshow(img)

# %%
a=cv2.norm(markerDetails[0][0],markerDetails[1][0])
b=cv2.norm(markerDetails[1][0],markerDetails[2][0])
c=cv2.norm(markerDetails[0][0],markerDetails[2][0])

# %%
a,b,c
# Out:
# (473.212425872356, 483.0838436544944, 636.3049583336593)

# %%
np.sqrt(a**2+b**2)
# Out:
# 676.2396025078685

# %%
markerDetails[0][0],markerDetails[1][0],markerDetails[2][0]
# Out:
# (array([527,  44], dtype=int16),
#  array([590, 513], dtype=int16),
#  array([107, 522], dtype=int16))

# %% [markdown]
# # Load predictions

# %%
file_name="../ehqnpwtj.txt"
predictions=[]
file = open(file_name).readlines()
for line in file:
        name_class,x1,y1,x2,y2,x3,y3,x4,y4=map(float,line.split())
        x1,y1,x2,y2,x3,y3,x4,y4=[np.round(x*640) for x in [x1,y1,x2,y2,x3,y3,x4,y4]]
        #cordinates=[np.round(np.array([[x1,y1],[x2,y2],[x3,y3],[x4,y4]])*640)]
        predictions.append([name_class,x1,y1,x2,y2,x3,y3,x4,y4])

predictions=np.array(predictions,dtype=np.float32)

# %%
predDetails={}
for pred in predictions:
    center, size, angle = cv2.minAreaRect(pred[1:].reshape(-1,1,2))
    predDetails[pred[0]]=[np.round(center),np.round(size),angle]
predDetails
# Out:
# {2.0: [array([323., 342.]), array([161.,  68.]), 9.286927223205566],
#  5.0: [array([466., 447.]), array([46., 99.]), 53.13010025024414],
#  1.0: [array([200., 336.]), array([ 37., 123.]), 1.3971812725067139]}

# %% [markdown]
# # Calculate it

# %%
#line1=markerDetails[1][0,1]-markerDetails[0][0,1]
#line2=markerDetails[1][0,0]-markerDetails[2][0,0]
line1=a
line2=b
line1,line2
# Out:
# (473.212425872356, 483.0838436544944)

# %%
line1_lenght=315
line2_lenght=330
y_zero=145
x_zero=50

# %%
x=(predDetails[2][0][1]-markerDetails[0][0,1])*(line1_lenght/line1)-x_zero
y=(markerDetails[1][0,0]-predDetails[2][0][0])*(line2_lenght/line2)-y_zero
x,-y
# Out:
# (148.3675720834102, -37.390699166120356)

# %%
x=(markerDetails[2][0,1]-markerDetails[0][0,1])*(line1_lenght/line1)-x_zero
y=(markerDetails[1][0,0]-markerDetails[2][0,0])*(line2_lenght/line2)-y_zero
y+=y/10
x,-y
# Out:
# (262.1959439836221, 159.5)

# %%
y+=y/10
-y
# Out:
# 191.18

# %%
markerDetails[1][0,1]
# Out:
# 513

# %%
(markerDetails[2][0,0]-markerDetails[1][0,0])
# Out:
# -483

# %%
305-145
# Out:
# 160

# %%
markerDetails
# Out:
# {2: array([[107, 522],
#         [ 31,  46]], dtype=int16),
#  1: array([[590, 513],
#         [ 46,  32]], dtype=int16),
#  0: array([[527,  44],
#         [ 29,  24]], dtype=int16)}

# %%
-50, 5
-100, 10
-200, 20
# Out:
# (-200, 20)
